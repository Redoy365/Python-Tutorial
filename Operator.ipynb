# %% [markdown]
# # Class 1 : trainer (smiritica shadukhan) Student (MD.Redoy Sarder)

# %%
a=2
b=2

# %%
a=b

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# True

# %%
a=b

# %%
a>=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a==b
# Out:
# True

# %%
# Data type

# %%
# int
# float
# string
# bool

# %%
my_int = 6

# %%
type(my_int)
# Out:
# int

# %%
my_float = 9.5

# %%
type(my_float)
# Out:
# float

# %%
x = "Hello World !"

# %%
type(x)
# Out:
# str

# %%
x
# Out:
# 'Hello World !'

# %%
# Data Structure

# %%
# list []
# set {}
# tuple ()
# dict {}

# %%
list1 = [2,2,5,8,9,3.6,'hello']
list1
# Out:
# [2, 2, 5, 8, 9, 3.6, 'hello']

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 7

# %%
list2 = [1,2,3]

# %%
len(list2)
# Out:
# 3

# %%
list3 = [1,2,3,4,5,6,7,8]

# %%
len(list3)
# Out:
# 8

# %%
list3[0]
# Out:
# 1

# %%
list3[7]
# Out:
# 8

# %%
list3[5:]
# Out:
# [6, 7, 8]

# %%
list3[:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
list3[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list3[::]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list3[2:5]
# Out:
# [3, 4, 5]

# %%
list3[:5:2]
# Out:
# [1, 3, 5]

# %%
# Negative index

# %%
2+3
# Out:
# 5

# %%
"Hello World !"
# Out:
# 'Hello World !'
